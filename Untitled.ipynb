# %% [markdown]
# Realizar un análisis exploratorio de los datos para identificar relaciones entre variables, valores atípicos, tendencias, etc

# %%
#Importamos las librerias 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %%
#Cargamos el dataset 
Datos = pd.read_csv('winequality-red.csv')
Datos.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# estadisticas del dataset
Datos.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
#para revisar datos vacios en Columnas
Datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# Grafica de histograma de la calidad de los vinos.
plt.hist(data.quality)
plt.xlabel('Nivel de calidad')
# Out:
# Text(0.5, 0, 'Nivel de calidad')

# %%
# De acuerdo a la literatura el alcohol y la acidez fija tienen un importante relacion con la calidad del vino Sáenz-Navajas, M.-P., Ballester, J., Fernández-Zurbano, P., Ferreira, V., Peyron, D., & Valentin, D. (2016). Wine Quality Perception: A Sensory Point of View. In Wine Safety, Consumer Preference, and Human Health (pp. 119–138). Springer. Link 2: MDPI. (2021). Measuring Wine Quality and Typicity. Beverages, 9(2), 41.
# Se observa que a mayor valor de alcohol mayor relacion hay con la calidad del vino
sns.scatterplot(x = "alcohol", y = "fixed acidity", hue = "quality", data = data)
# Out:
# <Axes: xlabel='alcohol', ylabel='fixed acidity'>

# %%
Datos.drop(columns=['residual sugar', 'chlorides', 'free sulfur dioxide', 'sulphates'])
Datos.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# definimos las variables de predicción y la variable objetivo
predictors_col = [col for col in Datos.columns if col != 'quality']
target_col = ['quality']

# %%
# division en dos partes del dataset,  predicción y datos objetivo
predictors = Datos[predictors_col]
target = Datos[target_col]

# %%
predictors
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
target
# Out:
#       quality
# 0           5
# 1           5
# 2           5
# 3           6
# 4           5
# ...       ...
# 1594        5
# 1595        6
# 1596        6
# 1597        5
# 1598        6
#
# [1599 rows x 1 columns]

# %%
# definición de  matriz de correlacion.
corr = predictors.corr()
corr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# ...

# %%
#grafica de correlacón 
sns.heatmap(corr)
plt.show()

# %%
# creacion de datos de entrenamiento  y de test.
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.25, random_state=13)

# %%
# creacion de un modelo de árboles de decisión utilizando el algoritmo DecisionTreeClassifier
tree = DecisionTreeClassifier()

# %%
# entrenamiento de el modelo de arbol de desición
arbol = tree.fit(X_train, y_train)

# %%
plot_tree(arbol)
# Out:
# [Text(0.4848217018243163, 0.9791666666666666, 'x[10] <= 10.525\ngini = 0.644\nsamples = 1199\nvalue = [8, 42, 500, 487, 150, 12]'),
#  Text(0.23555765182730204, 0.9375, 'x[9] <= 0.535\ngini = 0.542\nsamples = 725\nvalue = [5, 27, 423, 246, 24, 0]'),
#  Text(0.03989012301445121, 0.8958333333333334, 'x[1] <= 0.335\ngini = 0.369\nsamples = 173\nvalue = [2, 13, 135, 22, 1, 0]'),
#  Text(0.021019945061507225, 0.8541666666666666, 'x[2] <= 0.43\ngini = 0.54\nsamples = 10\nvalue = [0, 1, 3, 6, 0, 0]'),
#  Text(0.017198136868505912, 0.8125, 'x[9] <= 0.485\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 3, 1, 0, 0]'),
#  Text(0.013376328675504598, 0.7708333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.021019945061507225, 0.7708333333333334, 'x[3] <= 1.95\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.017198136868505912, 0.7291666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
# ...

# %%
# configuramos  la variable que contendra las predicciones utilizando el modelo de árbol de decisión (arbol) entrenado en un conjunto de datos de prueba (X_test).
predicciones = arbol.predict(X_test)

# %%
predicciones
# Out:
# array([7, 5, 5, 5, 6, 5, 6, 7, 5, 5, 5, 6, 5, 6, 7, 6, 6, 7, 5, 7, 5, 6,
#        7, 5, 6, 7, 5, 6, 5, 7, 7, 5, 5, 6, 5, 6, 5, 6, 6, 7, 5, 5, 6, 6,
#        5, 5, 6, 8, 6, 6, 6, 5, 6, 5, 7, 5, 5, 6, 6, 5, 5, 7, 5, 5, 7, 7,
#        6, 7, 5, 6, 6, 5, 7, 6, 5, 5, 5, 5, 5, 5, 6, 6, 6, 5, 6, 5, 7, 6,
#        6, 6, 6, 6, 4, 7, 7, 6, 5, 6, 6, 5, 6, 6, 5, 5, 7, 5, 5, 6, 5, 7,
#        7, 6, 6, 6, 5, 6, 6, 7, 5, 7, 7, 5, 5, 6, 5, 6, 5, 5, 6, 7, 6, 5,
#        6, 7, 5, 5, 7, 5, 6, 7, 5, 5, 6, 6, 7, 4, 6, 5, 6, 5, 5, 6, 5, 5,
#        5, 5, 6, 6, 6, 6, 6, 7, 6, 5, 6, 6, 6, 5, 6, 6, 5, 5, 5, 6, 6, 5,
#        5, 5, 5, 5, 5, 6, 6, 6, 5, 6, 6, 6, 5, 5, 5, 5, 5, 5, 6, 5, 6, 7,
#        5, 5, 6, 6, 5, 6, 7, 6, 6, 5, 5, 5, 6, 5, 5, 6, 7, 5, 6, 7, 5, 7,
#        5, 5, 7, 6, 5, 6, 5, 5, 6, 7, 6, 6, 6, 5, 5, 6, 6, 5, 6, 5, 6, 6,
#        5, 6, 5, 6, 8, 5, 5, 7, 6, 5, 5, 5, 6, 6, 7, 6, 5, 6, 6, 6, 7, 5,
#        6, 5, 6, 7, 6, 5, 7, 5, 5, 5, 6, 6, 6, 6, 5, 5, 5, 6, 5, 5, 7, 4,
# ...

# %%
# Examinamos la matriz de confusión  para evaluar el rendimiento del modelo
pd.crosstab(np.array([y[0] for y in y_test.values.tolist()]), predicciones, rownames=['Actual'], colnames=['Predicciones'])
# Out:
# Predicciones  3  4    5   6   7  8
# Actual
# 3             0  0    1   1   0  0
# 4             1  2    7   1   0  0
# 5             0  1  123  47  10  0
# 6             0  2   38  88  21  2
# 7             0  0    2  21  24  2
# 8             0  0    1   4   1  0

# %%
accuracy = accuracy_score(y_test,predicciones)
print("accuracy", accuracy)
f1 = f1_score(y_test, predicciones, average='weighted')
print("F1-Score:", f1)
recall = recall_score(y_test, predicciones, average='weighted')
print("Recall:", recall)
# Out:
# accuracy 0.5925
# F1-Score: 0.5904833139498049
# Recall: 0.5925

# %%
class_names = target['quality'].unique().astype(str)
plt.figure(figsize=(20, 10))
plot_tree(arbol, filled=True, feature_names=predictors_col, class_names=class_names)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(y_test, predicciones), annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicciones')
plt.ylabel('Valores reales')
plt.title('Matriz de confusión')
plt.show()

# %% [markdown]
# 8.Precisión (Accuracy):
# En nuestro caso, el modelo tiene una precisión del 59.25%. Esto significa que aproximadamente el 59.25% de las predicciones fueron correctas.
# Una precisión superior al 50% indica que el modelo está haciendo predicciones mejores que las que se obtendrían al azar.
# F1-Score:
# El F1-Score combina la precisión y el recall (sensibilidad) en una sola métrica.
# Un valor de 0.5905 indica un buen equilibrio entre la precisión y la capacidad del modelo para identificar correctamente las instancias positivas.
# Recall (Sensibilidad):
# El recall mide la proporción de instancias positivas que fueron correctamente clasificadas por el modelo.
# En nuestro caso, el recall también es del 59.25%, lo que significa que el 59.25% de todas las instancias positivas se identificaron correctamente.
# El modelo tiene un rendimiento aceptable, aunque no excelente.
# La precisión y el recall son similares, lo que sugiere que el modelo no está sesgado hacia ninguna clase en particular, aunque el modelo tiene un rendimiento razonable, es recomendable seguir explorando y afinando para obtener mejores resultados.
